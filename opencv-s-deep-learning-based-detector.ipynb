# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def load_face_detection_model(weights_path, arch_path):
    """
    Loads the DNN face detection model.
    """
    return cv2.dnn.readNetFromTensorflow(weights_path, arch_path)

# %%
def get_image_paths(base_path):
    """
    Walks through the base directory and returns a list of image file paths.
    """
    image_paths = []
    for root, dirs, files in os.walk(base_path):
        for file in files:
            if file.endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(root, file))
    return image_paths

# %%
def crop_faces_from_image(image, net, image_path):
    """
    Detects faces in the image and returns a list of cropped faces and corresponding labels.
    """
    cropped_faces = []
    labels = []
    
    blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300), [104., 177., 123.], False, False)
    net.setInput(blob)
    detections = net.forward()

    for i in range(0, detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        
        if confidence > 0.7:  # Confidence threshold
            box = detections[0, 0, i, 3:7] * np.array([image.shape[1], image.shape[0], image.shape[1], image.shape[0]])
            (startX, startY, endX, endY) = box.astype("int")

            # Crop the face
            cropped_face = image[startY:endY, startX:endX]
            
            # Store the cropped face and label (based on folder name)
            cropped_faces.append(cropped_face)
            labels.append(os.path.basename(os.path.dirname(image_path)))  # Label is folder name (person's name)
    
    return cropped_faces, labels

# %%
def save_cropped_faces(cropped_faces, labels, output_path, image_path):
    """
    Saves cropped faces to the output directory with corresponding labels.
    """
    person_folder = labels[0]  # Assuming all faces in one image are from the same person

    person_output_path = os.path.join(output_path, person_folder)
    if not os.path.exists(person_output_path):
        os.makedirs(person_output_path)

    for i, cropped_face in enumerate(cropped_faces):
        cropped_filename = os.path.join(person_output_path, f'{person_folder}_{os.path.basename(image_path)}_{i}.jpg')
        cv2.imwrite(cropped_filename, cropped_face)
        print(f"Saved cropped face: {cropped_filename}")

# %%
def process_images(image_paths, net, output_path):
    """
    Processes all images: detects faces, crops them, and saves them to the output path.
    """
    for image_path in image_paths:
        image = cv2.imread(image_path)
        
        # Detect faces and get the cropped faces and labels
        cropped_faces, labels = crop_faces_from_image(image, net, image_path)

        if cropped_faces:  # Only save if there are faces detected
            save_cropped_faces(cropped_faces, labels, output_path, image_path)

# %%
# Set the base path for your dataset and the output path
base_path = '/kaggle/input/pins-face-recognition/105_classes_pins_dataset/'
output_path = '/kaggle/working/cropped_faces/'

# Set the paths for the DNN model files
dnn_weights_path = '/kaggle/input/dnn/tensorflow2/default/1/opencv_face_detector_uint8.pb'
dnn_arch_path = '/kaggle/input/dnn/tensorflow2/default/1/opencv_face_detector.pbtxt'

# Load the face detection model
net = load_face_detection_model(dnn_weights_path, dnn_arch_path)

# Get image paths
image_paths = get_image_paths(base_path)

# Process images to detect faces and save cropped faces
process_images(image_paths, net, output_path)
# Out:
# Saved cropped face: /kaggle/working/cropped_faces/pins_Alex Lawther/pins_Alex Lawther_Alex Lawther233_93.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Alex Lawther/pins_Alex Lawther_Alex Lawther37_110.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Alex Lawther/pins_Alex Lawther_Alex Lawther228_91.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Alex Lawther/pins_Alex Lawther_Alex Lawther92_145.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Alex Lawther/pins_Alex Lawther_Alex Lawther40_113.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Alex Lawther/pins_Alex Lawther_Alex Lawther196_69.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Alex Lawther/pins_Alex Lawther_Alex Lawther159_45.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Alex Lawther/pins_Alex Lawther_Alex Lawther129_24.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Alex Lawther/pins_Alex Lawther_Alex Law
jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart56_2830.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart192_2772.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart200_2778.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart0_2713.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart146_2743.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart43_2822.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart108_2721.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart3_2815.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart135_2736.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart144_2742.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart118_2728.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart142_2741.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart71_2842.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart5_2826.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart226_2799.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart21_2787.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart208_2786.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart215_2793.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart81_2851.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart13_2733.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart197_2775.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart154_2752.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart102_2718.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart66_2835.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart19_2770.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart205_2784.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart190_2771.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart234_2802.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart73_2843.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart10_2715.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart98_2862.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart213_2790.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart26_2812.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart184_2769.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart9_2856.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart221_2795.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart39_2819.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart240_2805.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart204_2781.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart18_2765.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart78_2847.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart182_2767.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart45_2824.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart50_2827.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart97_2861.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart248_2810.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart74_2844.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart168_2760.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart179_2764.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart137_2737.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart141_2740.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart204_2783.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart95_2860.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart206_2785.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart28_2813.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart7_2840.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart86_2853.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart79_2848.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart25_2811.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart177_2763.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart245_2807.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart53_2828.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart201_2779.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart117_2727.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart85_2852.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart40_2821.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart8_2849.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart60_2833.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart128_2731.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart14_2738.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart213_2792.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart115_2726.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart34_2817.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart69_2839.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart154_2750.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart2_2777.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart63_2834.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart88_2854.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart247_2809.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart158_2755.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart44_2823.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart16_2757.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart156_2753.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart241_2806.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart15_2746.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart91_2858.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart94_2859.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart17_2762.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart126_2730.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart154_2751.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart1_2714.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart80_2850.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart194_2774.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart169_2761.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart246_2808.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart230_2801.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart68_2838.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart70_2841.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart99_2863.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart129_2732.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart134_2735.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart224_2797.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart89_2855.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart66_2836.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart113_2725.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart237_2803.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart105_2719.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart133_2734.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart146_2744.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart203_2780.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart229_2800.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart101_2717.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart90_2857.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart150_2747.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart157_2754.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart193_2773.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart181_2766.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart225_2798.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart47_2825.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart149_2745.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart55_2829.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart165_2759.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart152_2748.jpg_0.jpg
# Saved cropped face: /kaggle/working/cropped_faces/pins_Lili Reinhart/pins_Lili Reinhart_Lili Reinhart4_2820.jpg_0.jpg

# %%
import pandas as pd
import os

# List to store file paths and labels
data_records = []

# Define the output path where the cropped images are saved
output_path = '/kaggle/working/cropped_faces/'  # Ensure this matches your cropped image output path

# Loop through the output directory to collect file paths and labels
for label_folder in os.listdir(output_path):
    label_folder_path = os.path.join(output_path, label_folder)
    if os.path.isdir(label_folder_path):
        for file in os.listdir(label_folder_path):
            if file.endswith(('.jpg', '.jpeg', '.png')):
                file_path = os.path.join(label_folder_path, file)
                data_records.append({'image_path': file_path, 'label': label_folder})

# Convert list to DataFrame and save as CSV
df = pd.DataFrame(data_records)
df.to_csv('/kaggle/working/labels.csv', index=False)

# %%
import shutil

# Compress the entire directory of cropped faces and the labels CSV
shutil.make_archive('/kaggle/working/cropped_faces_dataset', 'zip', '/kaggle/working/cropped_faces')
shutil.copy('/kaggle/working/labels.csv', '/kaggle/working/cropped_faces_dataset')
# Out:
# '/kaggle/working/cropped_faces_dataset'
